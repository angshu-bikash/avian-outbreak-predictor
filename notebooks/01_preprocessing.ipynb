# %%
# 1. Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Plot settings
sns.set(style='whitegrid')

# %%
# 2. Load Dataset
file_path = '../data/Enhanced_Regression_Ready.csv'
data = pd.read_csv(file_path)

# Drop unnecessary columns
drop_cols = ['Month_Sin', 'Month_Cos', 'Unique_Diagnoses', 'Egg_Peritonitis_Flag']
data.drop(columns=[col for col in drop_cols if col in data.columns], inplace=True)

# Preview the data
display(data.head())
# Out:
#    Year    Month         Region  \
# 0  2020    March  East Midlands
# 1  2021    April  East Midlands
# 2  2022  October  East Midlands
# 3  2023    March  East Midlands
# 4  2023    April  East Midlands
#
#                                            Diagnoses  Case count  Season  \
# 0                          Coccidiosis, Helminthosis           3  Autumn
# 1  Egg peritonitis and salpingitis, Infectious br...           6  Autumn
# 2                                    Marek's Disease           1  Spring
# 3  Egg peritonitis and salpingitis, Marek's Disea...           3  Autumn
# 4         Neoplasm (other, including adenocarcinoma)           1  Autumn
#
#    Month_Num  Last_Month_Case_Count  Last_Year_Same_Month
# 0          3                      0                     0
# 1          4                      3                     0
# 2         10                      6                     0
# 3          3                      1                     3
# 4          4                      3                     6

# %%
# 3. Basic Data Overview
print("Data Info:")
data.info()

print("\nMissing values:")
print(data.isnull().sum())

print("\nSummary statistics (numerical):")
display(data.describe())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   274 non-null    int64
#  1   Month                  274 non-null    object
#  2   Region                 274 non-null    object
#  3   Diagnoses              274 non-null    object
#  4   Case count             274 non-null    int64
#  5   Season                 274 non-null    object
#  6   Month_Num              274 non-null    int64
#  7   Last_Month_Case_Count  274 non-null    int64
#  8   Last_Year_Same_Month   274 non-null    int64
# dtypes: int64(5), object(4)
# memory usage: 19.4+ KB
#
# Missing values:
# Year                     0
# Month                    0
# Region                   0
# Diagnoses                0
# Case count               0
# Season                   0
# Month_Num                0
# Last_Month_Case_Count    0
# Last_Year_Same_Month     0
# dtype: int64
#
# Summary statistics (numerical):
#               Year  Case count   Month_Num  Last_Month_Case_Count  \
# count   274.000000  274.000000  274.000000             274.000000
# mean   2020.255474    2.401460    6.675182               2.346715
# std       2.003766    1.959143    3.170428               2.003716
# min    2017.000000    1.000000    1.000000               0.000000
# 25%    2019.000000    1.000000    4.000000               1.000000
# 50%    2021.000000    2.000000    7.000000               2.000000
# 75%    2022.000000    3.000000    9.000000               3.000000
# max    2023.000000   11.000000   12.000000              11.000000
#
#        Last_Year_Same_Month
# count            274.000000
# mean               1.536496
# std                1.970604
# min                0.000000
# 25%                0.000000
# 50%                1.000000
# 75%                2.000000
# max               11.000000

# %%
print(data.isnull().sum())
# Out:
# Year                     0
# Month                    0
# Region                   0
# Diagnoses                0
# Case count               0
# Season                   0
# Month_Num                0
# Last_Month_Case_Count    0
# Last_Year_Same_Month     0
# Date                     0
# dtype: int64

# %%
data['Case count'] = data['Case count'].fillna(0)
data['Region'] = data['Region'].fillna('Unknown')

# %%
print("Duplicates:", data.duplicated().sum())
# Out:
# Duplicates: 0

# %%
# Step 1: Create "Month-Year" column
data['Month_Year'] = data.apply(lambda row: f"{row['Month']}-{row['Year']}", axis=1)

# Step 2: Group by Region and Month-Year, summing Case count
grouped = data.groupby(['Region', 'Month_Year'])['Case count'].sum().reset_index()

# Step 3: Filter where Case count > 1
filtered = grouped[grouped['Case count'] > 1]

# Step 4: Display the results
print("Region and Month-Year combinations with more than 1 case:\n")
for _, row in filtered.iterrows():
    print(f"{row['Region']} — {row['Month_Year']}: {int(row['Case count'])} cases")
# Out:
# Region and Month-Year combinations with more than 1 case:
#
# East Midlands — April-2021: 6 cases
# East Midlands — March-2020: 3 cases
# East Midlands — March-2023: 3 cases
# East of England — August-2020: 5 cases
# East of England — August-2022: 3 cases
# East of England — December-2017: 2 cases
# East of England — February-2017: 2 cases
# East of England — January-2022: 2 cases
# East of England — July-2020: 2 cases
# East of England — July-2021: 6 cases
# East of England — July-2022: 3 cases
# East of England — June-2023: 3 cases
# East of England — March-2023: 7 cases
# East of England — May-2022: 2 cases
# East of England — May-2023: 3 cases
# East of England — November-2023: 2 cases
# East of England — October-2023: 2 cases
# East of England — September-2020: 4 cases
# East of England — September-2022: 3 cases
# London — October-2023: 2 cases
# North East — December-2017: 2 cases
# North East — October-2017: 2 cases
# North West — April-2017: 2 cases
# North West — July-2022: 6 cases
# North West — June-2017: 2 cases
# North West — June-2020: 3 cases
# North West — May-2021: 2 cases
# North West — May-2023: 2 cases
# North West — November-2021: 6 cases
# Scotland — April-2017: 9 cases
# Scotland — August-2017: 2 cases
# Scotland — February-2017: 8 cases
# Scotland — January-2017: 8 cases
# Scotland — July-2017: 6 cases
# Scotland — July-2020: 2 cases
# Scotland — July-2022: 2 cases
# Scotland — June-2022: 3 cases
# Scotland — March-2017: 7 cases
# Scotland — May-2017: 6 cases
# Scotland — October-2017: 5 cases
# Scotland — October-2022: 2 cases
# Scotland — October-2023: 2 cases
# Scotland — September-2017: 4 cases
# South East — April-2019: 2 cases
# South East — August-2021: 4 cases
# South East — February-2020: 2 cases
# South East — July-2018: 2 cases
# South East — July-2020: 2 cases
# South East — June-2021: 10 cases
# South East — June-2023: 2 cases
# South East — March-2023: 2 cases
# South East — May-2021: 3 cases
# South East — May-2022: 3 cases
# South East — November-2019: 6 cases
# South East — October-2020: 5 cases
# South East — October-2022: 2 cases
# South East — October-2023: 2 cases
# South East — September-2020: 3 cases
# South East — September-2021: 3 cases
# South East — September-2022: 2 cases
# South West — April-2018: 4 cases
# South West — April-2019: 4 cases
# South West — April-2021: 6 cases
# South West — April-2022: 3 cases
# South West — August-2018: 4 cases
# South West — August-2019: 6 cases
# South West — August-2020: 6 cases
# South West — August-2021: 4 cases
# South West — August-2022: 2 cases
# South West — August-2023: 2 cases
# South West — December-2022: 2 cases
# South West — February-2019: 2 cases
# South West — February-2023: 2 cases
# South West — January-2018: 2 cases
# South West — January-2021: 9 cases
# South West — July-2019: 4 cases
# South West — July-2020: 5 cases
# South West — July-2021: 2 cases
# South West — July-2022: 4 cases
# South West — June-2018: 2 cases
# South West — June-2019: 4 cases
# South West — June-2020: 2 cases
# South West — June-2021: 5 cases
# South West — June-2022: 2 cases
# South West — March-2018: 3 cases
# South West — March-2019: 2 cases
# South West — March-2021: 4 cases
# South West — March-2022: 3 cases
# South West — May-2019: 5 cases
# South West — May-2021: 2 cases
# South West — November-2020: 5 cases
# South West — November-2021: 2 cases
# South West — November-2023: 3 cases
# South West — October-2017: 2 cases
# South West — September-2018: 8 cases
# South West — September-2019: 6 cases
# South West — September-2021: 8 cases
# South West — September-2022: 6 cases
# South West — September-2023: 2 cases
# Wales — April-2021: 4 cases
# Wales — April-2022: 7 cases
# Wales — August-2019: 2 cases
# Wales — August-2020: 4 cases
# Wales — August-2021: 2 cases
# Wales — August-2022: 2 cases
# Wales — December-2021: 4 cases
# Wales — January-2021: 8 cases
# Wales — July-2017: 2 cases
# Wales — July-2018: 2 cases
# Wales — July-2019: 4 cases
# Wales — July-2021: 6 cases
# Wales — July-2022: 4 cases
# Wales — June-2017: 4 cases
# Wales — June-2022: 2 cases
# Wales — March-2020: 2 cases
# Wales — March-2023: 3 cases
# Wales — May-2017: 2 cases
# Wales — May-2018: 3 cases
# Wales — May-2020: 3 cases
# Wales — May-2023: 6 cases
# Wales — November-2021: 5 cases
# Wales — November-2022: 4 cases
# Wales — October-2017: 2 cases
# Wales — October-2019: 4 cases
# Wales — October-2020: 2 cases
# Wales — October-2021: 2 cases
# Wales — September-2021: 2 cases
# Wales — September-2023: 3 cases
# West Midlands — December-2018: 3 cases
# West Midlands — January-2023: 3 cases
# West Midlands — July-2021: 6 cases
# West Midlands — June-2021: 2 cases
# West Midlands — June-2023: 2 cases
# West Midlands — May-2021: 7 cases
# West Midlands — September-2021: 5 cases
# Yorkshire and The Humber — April-2018: 2 cases
# Yorkshire and The Humber — August-2021: 2 cases
# Yorkshire and The Humber — December-2019: 4 cases
# Yorkshire and The Humber — January-2020: 2 cases
# Yorkshire and The Humber — July-2017: 2 cases
# Yorkshire and The Humber — July-2021: 11 cases
# Yorkshire and The Humber — July-2022: 2 cases
# Yorkshire and The Humber — June-2022: 2 cases
# Yorkshire and The Humber — May-2020: 5 cases
# Yorkshire and The Humber — September-2017: 2 cases
# Yorkshire and The Humber — September-2020: 2 cases
# Yorkshire and The Humber — September-2021: 5 cases

# %%
# Save to a new file
clean_path = '../data/cleaned_avian_data.csv'
data.to_csv(clean_path, index=False)

# %%
# !pip install meteostat
# Out:
# Collecting meteostat
#   Downloading meteostat-1.6.8-py3-none-any.whl (31 kB)
# Requirement already satisfied: pandas>=1.1 in c:\users\asus\anaconda3\lib\site-packages (from meteostat) (1.3.4)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from meteostat) (1.26.4)
# Requirement already satisfied: pytz in c:\users\asus\anaconda3\lib\site-packages (from meteostat) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=1.1->meteostat) (1.16.0)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.8

# %%
from meteostat import Point, Monthly
from datetime import datetime
from tqdm import tqdm
import calendar

# Load cleaned avian data
avian_df = pd.read_csv("../data/cleaned_avian_data.csv")

# Ensure Month_Num exists (or convert Month name to Month_Num)
if "Month_Num" not in avian_df.columns:
    avian_df["Month_Num"] = avian_df["Month"].apply(lambda x: list(calendar.month_name).index(x))

# Coordinates mapping
region_coords = {
    "East Midlands": Point(52.9, -1.0),
    "East of England": Point(52.3, 0.0),
    "London": Point(51.5, -0.1),
    "North East": Point(54.8, -1.6),
    "North West": Point(53.8, -2.4),
    "Scotland": Point(56.5, -4.2),
    "South East": Point(51.2, 0.5),
    "South West": Point(50.8, -3.5),
    "Wales": Point(52.3, -3.6),
    "West Midlands": Point(52.5, -2.0),
    "Yorkshire and The Humber": Point(53.9, -1.3),
}

# Add weather columns
avian_df["Avg_Temp_C"] = np.nan
avian_df["Avg_Humidity"] = np.nan

# Fetch Meteostat weather data
for idx, row in tqdm(avian_df.iterrows(), total=len(avian_df), desc="Fetching weather"):
    region = row["Region"]
    year = int(row["Year"])
    month = int(row["Month_Num"])

    if region not in region_coords:
        continue

    location = region_coords[region]
    start = datetime(year, month, 1)

    try:
        weather_data = Monthly(location, start, start).fetch()
        if not weather_data.empty:
            temp_val = weather_data.iloc[0].get("tavg", pd.NA)
            hum_val = weather_data.iloc[0].get("rhum", pd.NA)

            if pd.notna(temp_val):
                avian_df.at[idx, "Avg_Temp_C"] = round(temp_val, 1)

            if pd.notna(hum_val):
                avian_df.at[idx, "Avg_Humidity"] = round(hum_val, 1)

    except Exception as e:
        print(f"Error for {region} - {month}/{year}: {e}")

# Fill missing humidity with mean of available values
avian_df["Avg_Humidity"].fillna(avian_df["Avg_Humidity"].mean(), inplace=True)
avian_df["Avg_Temp_C"].fillna(avian_df["Avg_Temp_C"].mean(), inplace=True)

# Save result
avian_df.to_csv("../data/cleaned_avian_with_weather.csv", index=False)
print("✅ Weather-enhanced dataset saved.")
# Out:
# Fetching weather: 100%|██████████| 274/274 [00:14<00:00, 18.92it/s]
# ✅ Weather-enhanced dataset saved.

# %%
import pandas as pd

# Load the merged dataset
df = pd.read_csv("../data/cleaned_avian_with_weather.csv")

# Drop the Avg_Humidity column
df = df.drop(columns=['Avg_Humidity'])

# Save the cleaned file back
df.to_csv("../data/cleaned_avian_with_weather.csv", index=False)

print("Avg_Humidity column removed and file updated: cleaned_avian_with_weather.csv")
# Out:
# Avg_Humidity column removed and file updated: cleaned_avian_with_weather.csv
